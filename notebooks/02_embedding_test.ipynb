# %% [markdown]
# # Embedding Test
# Embed sample texts and inspect similarity behavior.

# %%
from app.ingestion.embedder import get_embedder

embedder = get_embedder()
vectors = embedder.embed_documents(['diabetes treatment', 'insulin therapy', 'heart disease'])
len(vectors), len(vectors[0])
