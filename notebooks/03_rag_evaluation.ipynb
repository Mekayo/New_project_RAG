# %% [markdown]
# # RAG Evaluation
# Run RAGAS metrics on a small QA set.

# %%
import pandas as pd

evaluation_df = pd.DataFrame([
    {'question': 'What is the study population?', 'faithfulness': None, 'answer_relevancy': None},
    {'question': 'What treatment improved outcomes?', 'faithfulness': None, 'answer_relevancy': None},
])
evaluation_df
